# %%
import pandas as pd
import csv

covid_dataset = pd.read_csv(r'/owid-covid-data-June06.csv')
covid_dataset.head()
# Out:
#   iso_code continent  ... life_expectancy human_development_index
# 0      AFG      Asia  ...           64.83                   0.511
# 1      AFG      Asia  ...           64.83                   0.511
# 2      AFG      Asia  ...           64.83                   0.511
# 3      AFG      Asia  ...           64.83                   0.511
# 4      AFG      Asia  ...           64.83                   0.511
#
# [5 rows x 59 columns]

# %%
covid_dataset.shape
# Out:
# (93532, 59)

# %%
covid_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93532 entries, 0 to 93531
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               93532 non-null  object
#  1   continent                              89106 non-null  object
#  2   location                               93532 non-null  object
#  3   date                                   93532 non-null  object
#  4   total_cases                            90554 non-null  float64
#  5   new_cases                              90553 non-null  float64
#  6   new_cases_smoothed                     89541 non-null  float64
#  7   total_deaths                           80607 non-null  float64
#  8   new_deaths                             80765 non-null  float64
#  9   new_deaths_smoothed                    89541 non-null  float64
# ...

# %%
covid_dataset.describe()
# Out:
#         total_cases     new_cases  ...  life_expectancy  human_development_index
# count  9.055400e+04  9.055300e+04  ...     88814.000000             84442.000000
# mean   9.587290e+05  6.074847e+03  ...        73.234003                 0.727680
# std    6.611396e+06  3.862363e+04  ...         7.560787                 0.150395
# min    1.000000e+00 -3.486670e+05  ...        53.280000                 0.394000
# 25%    1.110000e+03  2.000000e+00  ...        67.920000                 0.602000
# 50%    1.225450e+04  7.200000e+01  ...        74.620000                 0.748000
# 75%    1.293475e+05  7.920000e+02  ...        78.740000                 0.848000
# max    1.725886e+08  1.498126e+06  ...        86.750000                 0.957000
#
# [8 rows x 54 columns]

# %%
missing_percentage = covid_dataset.isna().mean().round(4) *100

missing_percentage.to_csv(r'/missing_percentage.csv')

# %%
covid_dataset.mean()
# Out:
# total_cases                              9.587290e+05
# new_cases                                6.074847e+03
# new_cases_smoothed                       6.086964e+03
# total_deaths                             2.570359e+04
# new_deaths                               1.469219e+02
# new_deaths_smoothed                      1.275277e+02
# total_cases_per_million                  1.177245e+04
# new_cases_per_million                    7.620909e+01
# new_cases_smoothed_per_million           7.640229e+01
# total_deaths_per_million                 2.558915e+02
# new_deaths_per_million                   1.564361e+00
# new_deaths_smoothed_per_million          1.357511e+00
# reproduction_rate                        1.007690e+00
# icu_patients                             1.088527e+03
# icu_patients_per_million                 2.706871e+01
# hosp_patients                            4.776076e+03
# hosp_patients_per_million                1.745895e+02
# ...

# %%
new_covid_dataset = covid_dataset[(covid_dataset['location'] == 'World') 
| (covid_dataset['location'] == 'France')
| (covid_dataset['location'] == 'Turkey')
| (covid_dataset['location'] == 'Russia')
| (covid_dataset['location'] == 'Brazil')
| (covid_dataset['location'] == 'Argentina')
| (covid_dataset['location'] == 'Colombia')
| (covid_dataset['location'] == 'United States')
| (covid_dataset['location'] == 'Mexico')
| (covid_dataset['location'] == 'Canada')
| (covid_dataset['location'] == 'India')
| (covid_dataset['location'] == 'Iran')
| (covid_dataset['location'] == 'Indonesia')
| (covid_dataset['location'] == 'South Africa')
| (covid_dataset['location'] == 'Morocco')
| (covid_dataset['location'] == 'Tunisia')
| (covid_dataset['location'] == 'United Kingdom')
| (covid_dataset['location'] == 'Italy')
| (covid_dataset['location'] == 'Australia')
| (covid_dataset['location'] == 'New Zealand')
| (covid_dataset['location'] == 'French Polynesia')
]

new_covid_dataset
# Out:
#        iso_code      continent  ... life_expectancy human_development_index
# 3342        ARG  South America  ...           76.67                   0.845
# 3343        ARG  South America  ...           76.67                   0.845
# 3344        ARG  South America  ...           76.67                   0.845
# 3345        ARG  South America  ...           76.67                   0.845
# 3346        ARG  South America  ...           76.67                   0.845
# ...         ...            ...  ...             ...                     ...
# 92220  OWID_WRL            NaN  ...           72.58                   0.737
# 92221  OWID_WRL            NaN  ...           72.58                   0.737
# 92222  OWID_WRL            NaN  ...           72.58                   0.737
# 92223  OWID_WRL            NaN  ...           72.58                   0.737
# 92224  OWID_WRL            NaN  ...           72.58                   0.737
#
# [9810 rows x 59 columns]

# %%
stats_by_country = new_covid_dataset.groupby("location").describe().reset_index()

stats_by_country.to_csv(r'/stats_by_country.csv')
